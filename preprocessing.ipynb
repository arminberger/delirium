# %% [markdown]
# # Preprocessing
#
# We preprocess the data twice: Once without imputing values, because this can be handled by the random forest models, and once with imputing values, because this is necessary for the MLP model.
#
# This file is self-contained to maximize readability and compatibility.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Paths

# %%
excel_path = './data/anonymized_data_dsl_project_5.xlsx'
save_data_path = './processed_data'

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
from os import path

# %% [markdown]
# ## Functions for data imputation

# %%
def drop_sparse_col(df, columns, threshold=0.5):
    for col in columns:
        if df[col].isnull().sum() / len(df) > threshold:
            print(f'Dropping column {col} with {df[col].isnull().sum() / len(df) * 100:.2f}% missing values')
            df.drop(col, axis=1, inplace=True)
        else:
            print(f'Keeping column {col} with {df[col].isnull().sum() / len(df) * 100:.2f}% missing values')
    print('###############################################')
    return

def fill_na(df, columns, how):
    if how == 'dominant':
        for col in columns:
            if col in df.columns:  # Check if the column exists in the DataFrame
                value = df[col].mode()[0]  # Get the dominant value (mode)
                dominant_class_frequency = df[col].value_counts().max()  # Get the frequency of the dominant class
                missing_values = df[col].isnull().sum()  # Get the number of missing values in the column
                print(f"Column: {col}, Dominant Class: {value}, Frequency: {dominant_class_frequency}, Missing Values: {missing_values}")
                df[col] = df[col].fillna(value)  # Fill missing values with the dominant class
            else:
                pass
    elif how == 'zero':
        for col in columns:
            if col in df.columns:
                print(f'Number of missing values in {col}: {df[col].isnull().sum()}, (filled with 0)')
                df[col] = df[col].fillna(0)
            else:
                pass
    elif how == 'mean':
        for col in columns:
            if col in df.columns:
                print(f'Number of missing values in {col}: {df[col].isnull().sum()}, (filled with mean)')
                df[col] = df[col].fillna(df[col].mean())
            else:
                pass
    else:
        print('Please specify the method to fill missing values')
    print('###############################################')
    return

def drop_na(df, columns):
    for col in columns:
        if col in df.columns:
            print(f'Number of missing values in {col}: {df[col].isnull().sum()}, (dropped)')
        else:
            print(f"Column '{col}' not found in the DataFrame.")

    # Drop rows with NA values in any of the specified columns, after the loop
    df = df.dropna(subset=[col for col in columns if col in df.columns])

    print('###############################################')
    return df


def one_hot_encode(df, column_name, map):
    df.loc[:, column_name] = df[column_name].map(map)
    print(f'Number of Nan values in {column_name}: {df[column_name].isnull().sum()}')
    df = pd.get_dummies(df, columns=[column_name], dummy_na=True)
    print(f'One-hot encoded column: {column_name}')
    print('###############################################')
    return df

def convert_bool_to_int(df):
    bool_columns = [col for col in df.columns if df[col].dtype == 'bool']
    df[bool_columns] = df[bool_columns].astype(int)
    return df

# %% [markdown]
# ## Mappings from given data representation to numerical values

# %%
renamed_columns = {
    'nu-desc_score_total_?': 'nu-desc_score_total_BI',
    '14_anxiety _nrs_0-10_BI': '14_anxiety_nrs_BI',
    '15:_stress_nrs _0-10_BI': '15_stress_nrs_BI',
    '18b:_vomiting_nrs _0-10_BI': '18b_vomiting_nrs_BI',
    '3:_asa-ps\n': '3:_asa-ps',
}


columns_to_drop = [ 'site',
          'baseline_no',
          'question_116',
          'appointment_id',
          'schema_version_id',
          'start_date',
          '0._date:',
          '8:_oral_consent',
          '30: suppression_time_total',
          '29:_satisfaction_with_BI',
          '30: minutes_of_anaesthesia_start_delay_(0_-_240min)',
          '29:_satisfaction_with_treatment_premedication_talk_AP',
          'sbi_team_handover_performed_arrival_pacu',
          '29:_satisfaction_with_treatment_premedication_talk_DP',
          'sbi_team_handover_performed_discharge_pacu',
          '9:_pain_BI', #summary column
          '9:_pain_DP', #summary column
          '9:_pain_HV', #summary column
          '9:_pain_AP', #summary column
          '5:_setting', #summary column
          '6:_anaesthesia', #summary column
          '7:_prevention', #summary column
          'nu-desc_score_total_AP',#summary column
          'nu-desc_score_total_DP',#summary column
          'nu-desc_score_total_HV',#summary column
          'nu-desc_score_total_BI',#summary column
          '27:_laryngeal_mask_BI', #summary column
          ]

post_op_map = {
    0: 'PACU',
    #1: 'ICU', #not in dataset
    2: 'WARD',
    3: 'IMCU' #renamed from Intermediate Care Unit
}

surigcal_specialty_map = {
    '0': 'General',
    '1': 'Trauma/Orth.',
    '2': 'Urology',
    '3': 'Gyn/Obs',
    '4': 'Ophtalmic',
    '5': 'Plastic/breast',
    '6': 'Otolaryngology',
    '7': 'Thoracic',
    '8': 'Neuro',
    '9': 'Cardiac',
    'a': 'Oral/maxilofacial',
    'b': 'Vascular',
    'c': 'Other'
}


laryngeal_map = {
    0: 'LMA',
    1: 'Tube',
    2: 'Muscle relaxants',
    3: 'Video laryngoscope',
    4: 'Other'
}

# %% [markdown]
# ## Loading the Excel file

# %%
df = pd.read_excel(excel_path)

# %% [markdown]
# # Processing the data

# %%
df.columns = df.columns.str.replace('\xa0', ' ', regex=True)
df.rename(columns=renamed_columns, inplace=True)
df.drop(columns_to_drop, axis=1, inplace=True)

df['Gender'] = df['Gender'].apply(lambda x: 1 if x == 'M' else (0 if x == 'F' else print("unknown gender")))

pain_columns = [col for col in df.columns if 'pain' in col.lower() and
                any(substring in col for substring in ['DP', 'HV', 'AP', 'BI'])]
drop_sparse_col(df, pain_columns, threshold=0.5)#0 is dominant and neutral

df = one_hot_encode(df, '2:_post-op', post_op_map)

df = one_hot_encode(df, '4:_surgical_speciality', surigcal_specialty_map)

setting_columns = [col for col in df.columns if 'setting' in col.lower()]

anaesthesia_columns = [col for col in df.columns if '_anaesthesia' in col.lower()]

prevention_columns = [col for col in df.columns if '_prevention' in col.lower()]

rass_columns = [col for col in df.columns if '_rass' in col.lower()]

nu_desc_substr = ['_disorientation', '_inappropriate_behavior',
              '_inappropriate_communication',
              'illusions/hallucinations', '_psychomotor_retardation']
nu_desc_cols = [col for col in df.columns if any(sub in col.lower() for sub in nu_desc_substr)]

moyb_columns = [col for col in df.columns if '_moyb_' in col.lower()]

anxiety_columns = [col for col in df.columns if 'anxiety' in col.lower()]

stress_columns = [col for col in df.columns if '_stress' in col.lower()]

well_being_columns = [col for col in df.columns if 'well-being' in col.lower()]

nausea_columns = [col for col in df.columns if 'nausea' in col.lower()]

vomit_columns = [col for col in df.columns if 'vomit' in col.lower()]

substrings = ['visual_aid', 'hearing_aid',
              'dentures']
aids_colums = [col for col in df.columns if any(sub in col.lower() for sub in substrings)]
fill_na(df, aids_colums, how='zero') #assume missing data = no = 0

fluid_columns = [col for col in df.columns if 'fluid' in col.lower()]

thirst_columns = [col for col in df.columns if 'thirst' in col.lower()]

temperature_columns = [col for col in df.columns if 'temperature' in col.lower()]

noise_columns = [col for col in df.columns if 'noise' in col.lower()]

shivering_columns = [col for col in df.columns if 'shivering' in col.lower()]

laryngeal_columns = [col for col in df.columns if 'laryngeal' in col.lower()]
laryngeal_binary_columns = [col for col in laryngeal_columns if df[col].isin([1, np.nan]).all()]
laryngeal_discomfort_columns = [col for col in laryngeal_columns if col not in laryngeal_binary_columns]
fill_na(df, laryngeal_discomfort_columns, how='dominant') # missing data means no discomfort

bladder_columns = [col for col in df.columns if 'bladder' in col.lower()]

quality_columns = [col for col in df.columns if 'quality' in col.lower()]

length_columns = [col for col in df.columns if 'length_of_patient_stay' in col.lower()]
# Out:
# Keeping column 9:_pain_BI_Resting_NRS with 0.21% missing values
# Dropping column 9:_pain_BI_Resting_BPS with 99.51% missing values
# Keeping column 9:_pain_BI_Mobilization_NRS with 0.91% missing values
# Dropping column 9:_pain_BI_Mobilization BPS with 99.65% missing values
# Keeping column 9:_pain_AP_Resting_NRS with 6.32% missing values
# Dropping column 9:_pain_AP_Resting_BPS with 94.81% missing values
# Keeping column 9:_pain_AP_Mobilization_NRS with 7.30% missing values
# Dropping column 9:_pain_AP_Mobilization BPS with 94.95% missing values
# Keeping column 9:_pain_DP_Resting_NRS with 0.70% missing values
# Dropping column 9:_pain_DP_Resting_BPS with 99.86% missing values
# Keeping column 9:_pain_DP_Mobilization_NRS with 2.88% missing values
# Dropping column 9:_pain_DP_Mobilization BPS with 99.86% missing values
# Keeping column 9:_pain_HV_Resting_NRS with 0.70% missing values
# Dropping column 9:_pain_HV_Resting_BPS with 95.72% missing values
# Keeping column 9:_pain_HV_Mobilization_NRS with 1.33% missing values
# Dropping column 9:_pain_HV_Mobilization BPS with 95.72% missing values
# ###############################################
# Number of Nan values in 2:_post-op: 4
# One-hot encoded column: 2:_post-op
# ###############################################
# Number of Nan values in 4:_surgical_speciality: 18
# One-hot encoded column: 4:_surgical_speciality
# ###############################################
# Number of missing values in 19:_patient_uses_visual_aids_BI: 6, (filled with 0)
# Number of missing values in 19a:_visual_aid_present_BI: 792, (filled with 0)
# Number of missing values in 20: patient_uses_hearing_aids_BI: 6, (filled with 0)
# Number of missing values in 20a:_hearing_aid_present_BI: 1342, (filled with 0)
# Number of missing values in 21: patient_uses_dentures_BI: 7, (filled with 0)
# Number of missing values in 21a: dentures_present_BI: 1299, (filled with 0)
# Number of missing values in 19a:_visual_aid_present_AP: 814, (filled with 0)
# Number of missing values in 20a:_hearing_aid_present_AP: 1343, (filled with 0)
# Number of missing values in 21a: dentures_present_AP: 1301, (filled with 0)
# ###############################################
# Column: 27:_laryngeal_mask_AP, Dominant Class: 0.0, Frequency: 623, Missing Values: 585
# Column: 27:_laryngeal_mask_DP, Dominant Class: 0.0, Frequency: 678, Missing Values: 521
# ###############################################
# /var/folders/kg/82lcvppx34n625kn45bnl_980000gn/T/ipykernel_93292/1232898196.py:56: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['PACU' 'PACU' 'PACU' ... 'PACU' 'IMCU' 'PACU']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, column_name] = df[column_name].map(map)

# %%
df = convert_bool_to_int(df)
# If a column has only 1s and NaNs, we can assume that the missing values are 0
# Find columns where this is the case, but if it is completely empty, we can't assume anything and should drop it
cols = df.columns
dropped_cols = []
for col in cols:
    if df[col].isna().sum() == len(df):
        df.drop(col, axis=1, inplace=True)
        dropped_cols.append(col)
    elif df[col].isna().sum() + df[col].sum() == len(df):
        df[col] = df[col].fillna(0)
print(f"Dropped columns: {dropped_cols} because they were completely empty")
# print all column names value counts and nan counts
counter = 0
nan_count_dict = {}
for column in df.columns:
    # Only print columns with NaN values
    if df[column].isna().sum() != 0:
        print(f"-----------{counter}-----------")
        print(f"\nValue counts for {column}:")
        print(df[column].value_counts())
        print(f"Number of NaN values for {column}: {df[column].isna().sum()}")
        nan_count_dict[column] = df[column].isna().sum()
        counter += 1
# print sorted nan counts
print(f"Sorted nan counts:")
sorted_nan_count_dict = dict(sorted(nan_count_dict.items(), key=lambda item: item[1]))
# Pretty print
for key, value in sorted_nan_count_dict.items():
    print(f"{key}: {value}")
# Save unprocessed df with NaN values into other variable
df_unprocessed = df.copy()
df_unprocessed.to_csv(path.join(save_data_path, 'df_not_imputed.csv'), index=False)
# Out:
# Dropped columns: ['(5:_setting)_Other_intervention', '6:_anaesthesia_Regional anaesthesia (nerve block; e.g., only blocking arm nerve for hand surgery. Not on brain, so should give less cognitive decline)', '6:_anaesthesia_Thorax and abdominal wall', '6:_anaesthesia_Head and Neck', '7:_prevention_PACU', '7:_prevention_OR'] because they were completely empty
# -----------0-----------
#
# Value counts for 3:_asa-ps:
# 3:_asa-ps
# 1.0    677
# 2.0    418
# 0.0    231
# 3.0      7
# Name: count, dtype: int64
# Number of NaN values for 3:_asa-ps: 92
# -----------1-----------
#
# Value counts for 9:_pain_BI_Resting_NRS:
# 9:_pain_BI_Resting_NRS
# 0.0     1001
# 2.0      105
# 3.0       76
# 5.0       59
# 4.0       51
# 1.0       48
# 6.0       36
# 7.0       25
# 8.0       17
# 10.0       2
# 9.0        2
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_BI_Resting_NRS: 3
# -----------2-----------
#
# Value counts for 9:_pain_BI_Mobilization_NRS:
# 9:_pain_BI_Mobilization_NRS
# 0.0     731
# 2.0      99
# 8.0      88
# 5.0      86
# 3.0      82
# 4.0      77
# 6.0      76
# 7.0      62
# 10.0     48
# 1.0      35
# 9.0      28
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_BI_Mobilization_NRS: 13
# -----------3-----------
#
# Value counts for 11:_rass_score_BI:
# 11:_rass_score_BI
#  0.0    1398
# -1.0       6
#  1.0       6
#  2.0       5
# -2.0       1
# Name: count, dtype: int64
# Number of NaN values for 11:_rass_score_BI: 9
# -----------4-----------
#
# Value counts for 12.1:_disorientation_BI:
# 12.1:_disorientation_BI
# 0.0    1409
# 1.0       9
# 2.0       5
# Name: count, dtype: int64
# Number of NaN values for 12.1:_disorientation_BI: 2
# -----------5-----------
#
# Value counts for 12.2:_inappropriate_behavior_BI:
# 12.2:_inappropriate_behavior_BI
# 0.0    1414
# 1.0       7
# 2.0       3
# Name: count, dtype: int64
# Number of NaN values for 12.2:_inappropriate_behavior_BI: 1
# -----------6-----------
#
# Value counts for 12.3:_inappropriate_communication_BI:
# 12.3:_inappropriate_communication_BI
# 0.0    1409
# 1.0      13
# 2.0       2
# Name: count, dtype: int64
# Number of NaN values for 12.3:_inappropriate_communication_BI: 1
# -----------7-----------
#
# Value counts for 12.4:_illusions/hallucinations_BI:
# 12.4:_illusions/hallucinations_BI
# 0.0    1419
# 1.0       4
# 2.0       1
# Name: count, dtype: int64
# Number of NaN values for 12.4:_illusions/hallucinations_BI: 1
# -----------8-----------
#
# Value counts for 12.5:_psychomotor_retardation_BI:
# 12.5:_psychomotor_retardation_BI
# 0.0    1409
# 1.0      13
# 2.0       1
# Name: count, dtype: int64
# Number of NaN values for 12.5:_psychomotor_retardation_BI: 2
# -----------9-----------
#
# Value counts for 13:_moyb_BI:
# 13:_moyb_BI
# 0.0    1340
# 1.0      38
# 2.0      22
# Name: count, dtype: int64
# Number of NaN values for 13:_moyb_BI: 25
# -----------10-----------
#
# Value counts for 14_anxiety_nrs_BI:
# 14_anxiety_nrs_BI
# 0.0     454
# 2.0     189
# 5.0     166
# 3.0     164
# 4.0     137
# 6.0      75
# 1.0      64
# 7.0      58
# 8.0      55
# 10.0     35
# 9.0      19
# Name: count, dtype: int64
# Number of NaN values for 14_anxiety_nrs_BI: 9
# -----------11-----------
#
# Value counts for 15_stress_nrs_BI:
# 15_stress_nrs_BI
# 0.0     319
# 2.0     201
# 3.0     170
# 5.0     167
# 4.0     152
# 6.0     117
# 7.0      81
# 8.0      77
# 1.0      62
# 10.0     43
# 9.0      29
# Name: count, dtype: int64
# Number of NaN values for 15_stress_nrs_BI: 7
# -----------12-----------
#
# Value counts for 16:_general_well-being_nrs _0-10_BI:
# 16:_general_well-being_nrs _0-10_BI
# 10.0    413
# 8.0     356
# 9.0     184
# 7.0     131
# 5.0     120
# 6.0     100
# 4.0      34
# 2.0      28
# 3.0      28
# 0.0      14
# 1.0       7
# Name: count, dtype: int64
# Number of NaN values for 16:_general_well-being_nrs _0-10_BI: 10
# -----------13-----------
#
# Value counts for 18a:_nausea_BI:
# 18a:_nausea_BI
# 0.0     1391
# 4.0        5
# 6.0        5
# 3.0        4
# 2.0        4
# 5.0        3
# 1.0        2
# 7.0        1
# 8.0        1
# 10.0       1
# Name: count, dtype: int64
# Number of NaN values for 18a:_nausea_BI: 8
# -----------14-----------
#
# Value counts for 18b_vomiting_nrs_BI:
# 18b_vomiting_nrs_BI
# 0.0    1399
# 1.0      14
# Name: count, dtype: int64
# Number of NaN values for 18b_vomiting_nrs_BI: 12
# -----------15-----------
#
# Value counts for 22:_fluids_p.o._>200_ml_BI:
# 22:_fluids_p.o._>200_ml_BI
# 4.0     240
# 3.0     163
# 6.0     155
# 5.0     150
# 2.0     135
# 12.0    119
# 10.0     81
# 8.0      73
# 7.0      61
# 9.0      46
# 11.0     35
# 13.0     30
# 14.0     25
# 15.0     18
# 16.0     17
# 1.0      10
# 17.0      3
# 20.0      3
# 0.0       2
# 21.0      1
# 19.0      1
# 24.0      1
# 18.0      1
# 22.0      1
# Name: count, dtype: int64
# Number of NaN values for 22:_fluids_p.o._>200_ml_BI: 54
# -----------16-----------
#
# Value counts for 23:_thirst_feeling: _nrs_0-10_BI:
# 23:_thirst_feeling: _nrs_0-10_BI
# 0.0     319
# 2.0     230
# 3.0     197
# 5.0     174
# 4.0     128
# 6.0     106
# 7.0      85
# 8.0      61
# 1.0      54
# 10.0     28
# 9.0      10
# Name: count, dtype: int64
# Number of NaN values for 23:_thirst_feeling: _nrs_0-10_BI: 33
# -----------17-----------
#
# Value counts for 24:_temperature _c_BI:
# 24:_temperature _c_BI
# 36.5    98
# 36.0    67
# 36.6    63
# 36.8    59
# 36.2    58
# 36.4    56
# 36.3    49
# 36.1    37
# 36.7    35
# 37.0    32
# 36.9    18
# 35.8    16
# 37.1    13
# 37.2    12
# 35.5    12
# 35.9    12
# 37.3    10
# 35.6     7
# 35.7     6
# 35.4     5
# 35.0     3
# 35.3     3
# 37.4     3
# 37.7     2
# 35.2     2
# 37.5     2
# 37.9     2
# 34.3     1
# 34.2     1
# Name: count, dtype: int64
# Number of NaN values for 24:_temperature _c_BI: 741
# -----------18-----------
#
# Value counts for 25:_noise_reduction_performed_BI:
# 25:_noise_reduction_performed_BI
# 0.0    955
# 1.0    234
# Name: count, dtype: int64
# Number of NaN values for 25:_noise_reduction_performed_BI: 236
# -----------19-----------
#
# Value counts for 26:_surgical_time_BI:
# 26:_surgical_time_BI
# 60.0     15
# 50.0     14
# 70.0     14
# 85.0     14
# 90.0     14
#          ..
# 177.0     1
# 31.0      1
# 14.0      1
# 17.0      1
# 275.0     1
# Name: count, Length: 215, dtype: int64
# Number of NaN values for 26:_surgical_time_BI: 661
# -----------20-----------
#
# Value counts for 28:_quality-evaluation_of_screening_BI:
# 28:_quality-evaluation_of_screening_BI
# 2.0    1291
# 1.0      85
# 0.0      10
# Name: count, dtype: int64
# Number of NaN values for 28:_quality-evaluation_of_screening_BI: 39
# -----------21-----------
#
# Value counts for 9:_pain_AP_Resting_NRS:
# 9:_pain_AP_Resting_NRS
# 0.0     965
# 2.0      61
# 3.0      60
# 5.0      52
# 4.0      47
# 6.0      45
# 8.0      31
# 7.0      30
# 1.0      27
# 10.0     10
# 9.0       7
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_AP_Resting_NRS: 90
# -----------22-----------
#
# Value counts for 9:_pain_AP_Mobilization_NRS:
# 9:_pain_AP_Mobilization_NRS
# 0.0     929
# 3.0      58
# 6.0      57
# 2.0      53
# 5.0      50
# 4.0      50
# 8.0      38
# 7.0      33
# 1.0      24
# 10.0     18
# 9.0      11
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_AP_Mobilization_NRS: 104
# -----------23-----------
#
# Value counts for 10:_shivering_AP:
# 10:_shivering_AP
# 0.0     1344
# 5.0       11
# 3.0       10
# 1.0        8
# 2.0        7
# 4.0        7
# 6.0        7
# 8.0        6
# 10.0       4
# 7.0        2
# Name: count, dtype: int64
# Number of NaN values for 10:_shivering_AP: 19
# -----------24-----------
#
# Value counts for 11:_rass_score_AP:
# 11:_rass_score_AP
#  0.0    1013
# -1.0     188
# -2.0      86
# -3.0      60
#  1.0      24
#  2.0      13
# -4.0      10
#  3.0       9
# -5.0       6
#  4.0       1
# Name: count, dtype: int64
# Number of NaN values for 11:_rass_score_AP: 15
# -----------25-----------
#
# Value counts for 12.1:_disorientation_AP:
# 12.1:_disorientation_AP
# 0.0    1204
# 2.0     138
# 1.0      73
# Name: count, dtype: int64
# Number of NaN values for 12.1:_disorientation_AP: 10
# -----------26-----------
#
# Value counts for 12.2:_inappropriate_behavior_AP:
# 12.2:_inappropriate_behavior_AP
# 0.0    1362
# 1.0      30
# 2.0      23
# Name: count, dtype: int64
# Number of NaN values for 12.2:_inappropriate_behavior_AP: 10
# -----------27-----------
#
# Value counts for 12.3:_inappropriate_communication_AP:
# 12.3:_inappropriate_communication_AP
# 0.0    1231
# 2.0     121
# 1.0      61
# Name: count, dtype: int64
# Number of NaN values for 12.3:_inappropriate_communication_AP: 12
# -----------28-----------
#
# Value counts for 12.4:_illusions/hallucinations_AP:
# 12.4:_illusions/hallucinations_AP
# 0.0    1379
# 1.0      23
# 2.0      10
# Name: count, dtype: int64
# Number of NaN values for 12.4:_illusions/hallucinations_AP: 13
# -----------29-----------
#
# Value counts for 12.5:_psychomotor_retardation_AP:
# 12.5:_psychomotor_retardation_AP
# 0.0    1018
# 1.0     211
# 2.0     184
# Name: count, dtype: int64
# Number of NaN values for 12.5:_psychomotor_retardation_AP: 12
# -----------30-----------
#
# Value counts for 13:_moyb_AP:
# 13:_moyb_AP
# 0.0    977
# 2.0    225
# 1.0    181
# Name: count, dtype: int64
# Number of NaN values for 13:_moyb_AP: 42
# -----------31-----------
#
# Value counts for 14_anxiety_AP:
# 14_anxiety_AP
# 0.0     965
# 2.0     114
# 1.0      61
# 3.0      53
# 4.0      33
# 5.0      28
# 6.0      12
# 8.0       7
# 10.0      6
# 7.0       6
# 9.0       5
# Name: count, dtype: int64
# Number of NaN values for 14_anxiety_AP: 135
# -----------32-----------
#
# Value counts for 15:_stress_AP:
# 15:_stress_AP
# 0.0     970
# 2.0     125
# 1.0      55
# 3.0      49
# 5.0      32
# 4.0      27
# 8.0       9
# 10.0      8
# 6.0       7
# 7.0       6
# 9.0       3
# Name: count, dtype: int64
# Number of NaN values for 15:_stress_AP: 134
# -----------33-----------
#
# Value counts for 16:_general_well-being_AP:
# 16:_general_well-being_AP
# 10.0    583
# 8.0     251
# 9.0     158
# 7.0      91
# 6.0      60
# 5.0      50
# 0.0      39
# 4.0      15
# 2.0      13
# 3.0      13
# 1.0      11
# Name: count, dtype: int64
# Number of NaN values for 16:_general_well-being_AP: 141
# -----------34-----------
#
# Value counts for 17:_bladder_AP:
# 17:_bladder_AP
# 0.0    1054
# 1.0     335
# Name: count, dtype: int64
# Number of NaN values for 17:_bladder_AP: 36
# -----------35-----------
#
# Value counts for 18a:_nausea_AP:
# 18a:_nausea_AP
# 0.0     1382
# 1.0        3
# 10.0       3
# 2.0        3
# 7.0        2
# 8.0        2
# 5.0        2
# 6.0        2
# 3.0        1
# 9.0        1
# Name: count, dtype: int64
# Number of NaN values for 18a:_nausea_AP: 24
# -----------36-----------
#
# Value counts for 18b:_vomiting_AP:
# 18b:_vomiting_AP
# 0.0    1392
# 1.0      10
# Name: count, dtype: int64
# Number of NaN values for 18b:_vomiting_AP: 23
# -----------37-----------
#
# Value counts for 23:_thirst_feeling_AP:
# 23:_thirst_feeling_AP
# 0.0     262
# 2.0     157
# 5.0     139
# 3.0     134
# 4.0     105
# 8.0      90
# 7.0      83
# 6.0      82
# 1.0      48
# 10.0     32
# 9.0      18
# Name: count, dtype: int64
# Number of NaN values for 23:_thirst_feeling_AP: 275
# -----------38-----------
#
# Value counts for 24:_temperature _AP:
# 24:_temperature _AP
# 36.0    125
# 35.8     45
# 36.5     41
# 36.2     40
# 36.4     39
# 36.3     26
# 35.9     24
# 36.1     24
# 37.0     23
# 36.8     23
# 35.5     22
# 36.6     18
# 35.4     18
# 35.7     15
# 35.0     15
# 36.9     14
# 35.2     14
# 36.7     14
# 35.6     14
# 35.3     11
# 37.2      8
# 34.7      7
# 37.1      6
# 35.1      6
# 37.3      5
# 37.4      4
# 34.8      3
# 37.5      3
# 34.9      3
# 34.5      2
# 33.5      1
# 37.6      1
# 34.6      1
# 37.9      1
# 34.0      1
# 38.5      1
# Name: count, dtype: int64
# Number of NaN values for 24:_temperature _AP: 807
# -----------39-----------
#
# Value counts for 28:_quality-evaluation_of_screening_AP:
# 28:_quality-evaluation_of_screening_AP
# 2.0    1002
# 1.0     220
# 0.0     103
# Name: count, dtype: int64
# Number of NaN values for 28:_quality-evaluation_of_screening_AP: 100
# -----------40-----------
#
# Value counts for 9:_pain_DP_Resting_NRS:
# 9:_pain_DP_Resting_NRS
# 0.0    741
# 3.0    223
# 2.0    191
# 1.0     91
# 4.0     86
# 5.0     53
# 6.0     19
# 7.0      7
# 8.0      2
# 9.0      2
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_DP_Resting_NRS: 10
# -----------41-----------
#
# Value counts for 9:_pain_DP_Mobilization_NRS:
# 9:_pain_DP_Mobilization_NRS
# 0.0     685
# 3.0     221
# 2.0     151
# 4.0     123
# 5.0      79
# 1.0      60
# 6.0      33
# 7.0      20
# 8.0       9
# 10.0      2
# 9.0       1
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_DP_Mobilization_NRS: 41
# -----------42-----------
#
# Value counts for 10:_shivering_DP:
# 10:_shivering_DP
# 0.0    1382
# 2.0       9
# 4.0       7
# 3.0       5
# 1.0       4
# 5.0       2
# 6.0       1
# Name: count, dtype: int64
# Number of NaN values for 10:_shivering_DP: 15
# -----------43-----------
#
# Value counts for 11:_rass_score_DP:
# 11:_rass_score_DP
#  0.0    1375
# -1.0      22
# -3.0       4
# -2.0       2
#  1.0       2
#  2.0       2
# -5.0       1
#  3.0       1
# Name: count, dtype: int64
# Number of NaN values for 11:_rass_score_DP: 16
# -----------44-----------
#
# Value counts for 12.1:_disorientation_DP:
# 12.1:_disorientation_DP
# 0.0    1410
# 1.0       9
# 2.0       2
# Name: count, dtype: int64
# Number of NaN values for 12.1:_disorientation_DP: 4
# -----------45-----------
#
# Value counts for 12.2:_inappropriate_behavior_DP:
# 12.2:_inappropriate_behavior_DP
# 0.0    1412
# 1.0       8
# 2.0       1
# Name: count, dtype: int64
# Number of NaN values for 12.2:_inappropriate_behavior_DP: 4
# -----------46-----------
#
# Value counts for 12.3:_inappropriate_communication_DP:
# 12.3:_inappropriate_communication_DP
# 0.0    1413
# 1.0       6
# 2.0       2
# Name: count, dtype: int64
# Number of NaN values for 12.3:_inappropriate_communication_DP: 4
# -----------47-----------
#
# Value counts for 12.4:_illusions/hallucinations_DP:
# 12.4:_illusions/hallucinations_DP
# 0.0    1413
# 1.0       5
# 2.0       1
# Name: count, dtype: int64
# Number of NaN values for 12.4:_illusions/hallucinations_DP: 6
# -----------48-----------
#
# Value counts for 12.5:_psychomotor_retardation_DP:
# 12.5:_psychomotor_retardation_DP
# 0.0    1383
# 1.0      33
# 2.0       5
# Name: count, dtype: int64
# Number of NaN values for 12.5:_psychomotor_retardation_DP: 4
# -----------49-----------
#
# Value counts for 13:_moyb_DP:
# 13:_moyb_DP
# 0.0    1336
# 1.0      50
# 2.0      14
# Name: count, dtype: int64
# Number of NaN values for 13:_moyb_DP: 25
# -----------50-----------
#
# Value counts for 14_anxiety_DP:
# 14_anxiety_DP
# 0.0     1091
# 2.0       92
# 1.0       83
# 3.0       54
# 5.0       29
# 4.0       28
# 6.0       12
# 8.0        7
# 7.0        5
# 10.0       5
# 9.0        3
# Name: count, dtype: int64
# Number of NaN values for 14_anxiety_DP: 16
# -----------51-----------
#
# Value counts for 15:_stress_DP:
# 15:_stress_DP
# 0.0     1156
# 2.0       90
# 1.0       65
# 3.0       44
# 4.0       21
# 5.0       19
# 6.0        4
# 8.0        3
# 10.0       3
# 9.0        3
# 7.0        2
# Name: count, dtype: int64
# Number of NaN values for 15:_stress_DP: 15
# -----------52-----------
#
# Value counts for 16:_general_well-being_DP:
# 16:_general_well-being_DP
# 10.0    627
# 8.0     297
# 9.0     230
# 7.0      88
# 5.0      43
# 6.0      38
# 0.0      38
# 2.0      13
# 1.0      12
# 4.0      10
# 3.0       9
# Name: count, dtype: int64
# Number of NaN values for 16:_general_well-being_DP: 20
# -----------53-----------
#
# Value counts for 17:_bladder_DP:
# 17:_bladder_DP
# 0.0    1060
# 1.0     343
# Name: count, dtype: int64
# Number of NaN values for 17:_bladder_DP: 22
# -----------54-----------
#
# Value counts for 18a:_nausea_DP:
# 18a:_nausea_DP
# 0.0     1362
# 1.0        6
# 6.0        4
# 3.0        4
# 2.0        4
# 5.0        3
# 10.0       2
# 4.0        2
# 8.0        2
# 9.0        1
# Name: count, dtype: int64
# Number of NaN values for 18a:_nausea_DP: 35
# -----------55-----------
#
# Value counts for 18b:_vomiting_DP:
# 18b:_vomiting_DP
# 0.0    1398
# 1.0      13
# Name: count, dtype: int64
# Number of NaN values for 18b:_vomiting_DP: 14
# -----------56-----------
#
# Value counts for 22:_fluids_p.o._>200_ml_DP:
# 22:_fluids_p.o._>200_ml_DP
# 1.0    1190
# 0.0     161
# Name: count, dtype: int64
# Number of NaN values for 22:_fluids_p.o._>200_ml_DP: 74
# -----------57-----------
#
# Value counts for 23:_thirst_feeling:_DP:
# 23:_thirst_feeling:_DP
# 0.0     472
# 2.0     200
# 3.0     130
# 5.0      99
# 1.0      89
# 4.0      77
# 7.0      42
# 6.0      41
# 8.0      28
# 10.0     17
# 9.0       7
# Name: count, dtype: int64
# Number of NaN values for 23:_thirst_feeling:_DP: 223
# -----------58-----------
#
# Value counts for 24:_temperature_DP:
# 24:_temperature_DP
# 36.0    223
# 36.2     74
# 36.1     72
# 36.5     68
# 35.8     61
# 36.3     57
# 36.4     52
# 35.6     49
# 35.9     46
# 36.6     43
# 36.7     36
# 36.8     33
# 35.7     32
# 35.5     31
# 35.0     23
# 35.4     20
# 37.0     16
# 36.9     15
# 35.2     14
# 35.1     10
# 37.2     10
# 35.3     10
# 34.9      7
# 34.8      6
# 37.1      5
# 37.4      4
# 37.3      3
# 34.5      3
# 38.0      2
# 37.5      2
# 34.7      2
# 38.8      2
# 39.4      1
# 34.3      1
# 34.4      1
# 34.6      1
# 37.8      1
# Name: count, dtype: int64
# Number of NaN values for 24:_temperature_DP: 389
# -----------59-----------
#
# Value counts for 25:_noise_reduction_DP:
# 25:_noise_reduction_DP
# 0.0    1038
# 1.0      37
# Name: count, dtype: int64
# Number of NaN values for 25:_noise_reduction_DP: 350
# -----------60-----------
#
# Value counts for 28:_quality-evaluation_of_screening_DP:
# 28:_quality-evaluation_of_screening_DP
# 2.0    1293
# 1.0      66
# 0.0      15
# Name: count, dtype: int64
# Number of NaN values for 28:_quality-evaluation_of_screening_DP: 51
# -----------61-----------
#
# Value counts for 31: length_of_patient_stay_in_pacu/recovery_room:
# 31: length_of_patient_stay_in_pacu/recovery_room
# 90.0      75
# 85.0      72
# 105.0     61
# 70.0      57
# 80.0      55
#           ..
# 1140.0     1
# 171.0      1
# 1305.0     1
# 860.0      1
# 84.0       1
# Name: count, Length: 227, dtype: int64
# Number of NaN values for 31: length_of_patient_stay_in_pacu/recovery_room: 51
# -----------62-----------
#
# Value counts for 9:_pain_HV_Resting_NRS:
# 9:_pain_HV_Resting_NRS
# 0.0     695
# 3.0     178
# 2.0     155
# 4.0      88
# 5.0      81
# 1.0      74
# 6.0      56
# 7.0      35
# 8.0      34
# 10.0     10
# 9.0       9
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_HV_Resting_NRS: 10
# -----------63-----------
#
# Value counts for 9:_pain_HV_Mobilization_NRS:
# 9:_pain_HV_Mobilization_NRS
# 0.0     660
# 3.0     176
# 2.0     126
# 4.0      97
# 5.0      87
# 6.0      78
# 1.0      50
# 7.0      48
# 8.0      44
# 10.0     22
# 9.0      18
# Name: count, dtype: int64
# Number of NaN values for 9:_pain_HV_Mobilization_NRS: 19
# -----------64-----------
#
# Value counts for 10:_shivering_HV:
# 10:_shivering_HV
# 0.0     1343
# 3.0       14
# 5.0       12
# 2.0       11
# 4.0       11
# 1.0        7
# 6.0        6
# 8.0        5
# 10.0       4
# 7.0        2
# Name: count, dtype: int64
# Number of NaN values for 10:_shivering_HV: 10
# -----------65-----------
#
# Value counts for 11:_rass_score_HV:
# 11:_rass_score_HV
#  0.0    1029
# -1.0     185
# -2.0      83
# -3.0      57
#  1.0      21
#  2.0      11
#  3.0      11
# -4.0       9
# -5.0       6
#  4.0       1
# Name: count, dtype: int64
# Number of NaN values for 11:_rass_score_HV: 12
# -----------66-----------
#
# Value counts for 12.1:_disorientation_HV:
# 12.1:_disorientation_HV
# 0.0    1210
# 2.0     136
# 1.0      72
# Name: count, dtype: int64
# Number of NaN values for 12.1:_disorientation_HV: 7
# -----------67-----------
#
# Value counts for 12.2:_inappropriate_behavior_HV:
# 12.2:_inappropriate_behavior_HV
# 0.0    1357
# 1.0      34
# 2.0      23
# Name: count, dtype: int64
# Number of NaN values for 12.2:_inappropriate_behavior_HV: 11
# -----------68-----------
#
# Value counts for 12.3:_inappropriate_communication_HV:
# 12.3:_inappropriate_communication_HV
# 0.0    1240
# 2.0     118
# 1.0      61
# Name: count, dtype: int64
# Number of NaN values for 12.3:_inappropriate_communication_HV: 6
# -----------69-----------
#
# Value counts for 12.4:_illusions/hallucinations_HV:
# 12.4:_illusions/hallucinations_HV
# 0.0    1382
# 1.0      24
# 2.0      10
# Name: count, dtype: int64
# Number of NaN values for 12.4:_illusions/hallucinations_HV: 9
# -----------70-----------
#
# Value counts for 12.5:_psychomotor_retardation_HV:
# 12.5:_psychomotor_retardation_HV
# 0.0    1024
# 1.0     213
# 2.0     181
# Name: count, dtype: int64
# Number of NaN values for 12.5:_psychomotor_retardation_HV: 7
# -----------71-----------
#
# Value counts for 13:_moyb_HV:
# 13:_moyb_HV
# 0.0    1009
# 2.0     215
# 1.0     179
# Name: count, dtype: int64
# Number of NaN values for 13:_moyb_HV: 22
# -----------72-----------
#
# Value counts for 14_anxiety_HV:
# 14_anxiety_HV
# 0.0     960
# 2.0     140
# 1.0      77
# 3.0      75
# 4.0      52
# 5.0      46
# 6.0      22
# 7.0      12
# 10.0     10
# 8.0       9
# 9.0       8
# Name: count, dtype: int64
# Number of NaN values for 14_anxiety_HV: 14
# -----------73-----------
#
# Value counts for 15:_stress_nrs_HV:
# 15:_stress_nrs_HV
# 0.0     985
# 2.0     155
# 3.0      69
# 1.0      65
# 5.0      45
# 4.0      43
# 6.0      13
# 7.0      10
# 10.0     10
# 8.0       9
# 9.0       7
# Name: count, dtype: int64
# Number of NaN values for 15:_stress_nrs_HV: 14
# -----------74-----------
#
# Value counts for 16:_general_well-being_nrs_HV:
# 16:_general_well-being_nrs_HV
# 10.0    770
# 8.0     265
# 9.0     213
# 7.0      61
# 6.0      35
# 5.0      23
# 0.0      17
# 3.0       9
# 2.0       8
# 1.0       6
# 4.0       5
# Name: count, dtype: int64
# Number of NaN values for 16:_general_well-being_nrs_HV: 13
# -----------75-----------
#
# Value counts for 18a:_nausea_HV:
# 18a:_nausea_HV
# 0.0     1378
# 1.0        6
# 6.0        5
# 5.0        5
# 2.0        5
# 10.0       4
# 7.0        2
# 3.0        2
# 8.0        1
# 4.0        1
# Name: count, dtype: int64
# Number of NaN values for 18a:_nausea_HV: 16
# Sorted nan counts:
# 12.2:_inappropriate_behavior_BI: 1
# 12.3:_inappropriate_communication_BI: 1
# 12.4:_illusions/hallucinations_BI: 1
# 12.1:_disorientation_BI: 2
# 12.5:_psychomotor_retardation_BI: 2
# 9:_pain_BI_Resting_NRS: 3
# 12.1:_disorientation_DP: 4
# 12.2:_inappropriate_behavior_DP: 4
# 12.3:_inappropriate_communication_DP: 4
# 12.5:_psychomotor_retardation_DP: 4
# 12.4:_illusions/hallucinations_DP: 6
# 12.3:_inappropriate_communication_HV: 6
# 15_stress_nrs_BI: 7
# 12.1:_disorientation_HV: 7
# 12.5:_psychomotor_retardation_HV: 7
# 18a:_nausea_BI: 8
# 11:_rass_score_BI: 9
# 14_anxiety_nrs_BI: 9
# 12.4:_illusions/hallucinations_HV: 9
# 16:_general_well-being_nrs _0-10_BI: 10
# 12.1:_disorientation_AP: 10
# 12.2:_inappropriate_behavior_AP: 10
# 9:_pain_DP_Resting_NRS: 10
# 9:_pain_HV_Resting_NRS: 10
# 10:_shivering_HV: 10
# 12.2:_inappropriate_behavior_HV: 11
# 18b_vomiting_nrs_BI: 12
# 12.3:_inappropriate_communication_AP: 12
# 12.5:_psychomotor_retardation_AP: 12
# 11:_rass_score_HV: 12
# 9:_pain_BI_Mobilization_NRS: 13
# 12.4:_illusions/hallucinations_AP: 13
# 16:_general_well-being_nrs_HV: 13
# 18b:_vomiting_DP: 14
# 14_anxiety_HV: 14
# 15:_stress_nrs_HV: 14
# 11:_rass_score_AP: 15
# 10:_shivering_DP: 15
# 15:_stress_DP: 15
# 11:_rass_score_DP: 16
# 14_anxiety_DP: 16
# 18a:_nausea_HV: 16
# 10:_shivering_AP: 19
# 9:_pain_HV_Mobilization_NRS: 19
# 16:_general_well-being_DP: 20
# 17:_bladder_DP: 22
# 13:_moyb_HV: 22
# 18b:_vomiting_AP: 23
# 18a:_nausea_AP: 24
# 13:_moyb_BI: 25
# 13:_moyb_DP: 25
# 23:_thirst_feeling: _nrs_0-10_BI: 33
# 18a:_nausea_DP: 35
# 17:_bladder_AP: 36
# 28:_quality-evaluation_of_screening_BI: 39
# 9:_pain_DP_Mobilization_NRS: 41
# 13:_moyb_AP: 42
# 28:_quality-evaluation_of_screening_DP: 51
# 31: length_of_patient_stay_in_pacu/recovery_room: 51
# 22:_fluids_p.o._>200_ml_BI: 54
# 22:_fluids_p.o._>200_ml_DP: 74
# 9:_pain_AP_Resting_NRS: 90
# 3:_asa-ps: 92
# 28:_quality-evaluation_of_screening_AP: 100
# 9:_pain_AP_Mobilization_NRS: 104
# 15:_stress_AP: 134
# 14_anxiety_AP: 135
# 16:_general_well-being_AP: 141
# 23:_thirst_feeling:_DP: 223
# 25:_noise_reduction_performed_BI: 236
# 23:_thirst_feeling_AP: 275
# 25:_noise_reduction_DP: 350
# 24:_temperature_DP: 389
# 26:_surgical_time_BI: 661
# 24:_temperature _c_BI: 741
# 24:_temperature _AP: 807

# %% [markdown]
# ## Imputation using simple heuristics

# %%
fill_na(df, pain_columns, how='dominant') 
fill_na(df, ['3:_asa-ps'], how='dominant')
fill_na(df, setting_columns, how='zero') #assume missing missing data = no = 0
fill_na(df, anaesthesia_columns, how='zero') #assume missing missing data = no = 0
fill_na(df, prevention_columns, how='zero') #assume missing data = no = 0
fill_na(df, rass_columns, how='zero') #assume neutral more likely not to be registered
fill_na(df, nu_desc_cols, how='dominant')
fill_na(df, moyb_columns, how='zero') #assume missing data = no = 0
fill_na(df, anxiety_columns, how='zero') #assume missing data = no = 0
fill_na(df, stress_columns, how='zero') #assume missing data = no = 0
fill_na(df, well_being_columns, how='dominant') #assume missing data = unremarkable
fill_na(df, nausea_columns, how='zero') #assume missing data = no = 0
fill_na(df, vomit_columns, how='zero') #assume missing data = no = 0
fill_na(df, aids_colums, how='zero') #assume missing data = no = 0
fill_na(df, [fluid_columns[0]], how='mean')  #before induction, no other obvisous choice
fill_na(df, [fluid_columns[1]], how='zero')  #pacu, assume missing data = no = 0
fill_na(df, thirst_columns, how='mean') #no clear dominant choice
fill_na(df, temperature_columns, how='dominant') #no measurement = no fever
fill_na(df, noise_columns, how='zero') #assume missing data = no = 0
fill_na(df, shivering_columns, how='dominant') #assume missing data = no = 0
fill_na(df, bladder_columns, how='zero') #assume missing data = no = 0
fill_na(df, quality_columns, how='dominant') #assume missing data = unremarkable
fill_na(df, length_columns, how='mean') #no clear dominant choice
# fill_na(df, ["26:_surgical_time_BI"], how='mean') #no clear dominant choice
df.to_csv(path.join(save_data_path, 'df_imputed.csv'), index=False)
# Out:
# Column: 9:_pain_BI_Resting_NRS, Dominant Class: 0.0, Frequency: 1001, Missing Values: 3
# Column: 9:_pain_BI_Mobilization_NRS, Dominant Class: 0.0, Frequency: 731, Missing Values: 13
# Column: 9:_pain_AP_Resting_NRS, Dominant Class: 0.0, Frequency: 965, Missing Values: 90
# Column: 9:_pain_AP_Mobilization_NRS, Dominant Class: 0.0, Frequency: 929, Missing Values: 104
# Column: 9:_pain_DP_Resting_NRS, Dominant Class: 0.0, Frequency: 741, Missing Values: 10
# Column: 9:_pain_DP_Mobilization_NRS, Dominant Class: 0.0, Frequency: 685, Missing Values: 41
# Column: 9:_pain_HV_Resting_NRS, Dominant Class: 0.0, Frequency: 695, Missing Values: 10
# Column: 9:_pain_HV_Mobilization_NRS, Dominant Class: 0.0, Frequency: 660, Missing Values: 19
# ###############################################
# Column: 3:_asa-ps, Dominant Class: 1.0, Frequency: 677, Missing Values: 92
# ###############################################
# Number of missing values in (5:_setting)_Elective: 0, (filled with 0)
# Number of missing values in (5:_setting)_Acute: 0, (filled with 0)
# Number of missing values in (5:_setting)_Inpatient: 0, (filled with 0)
# Number of missing values in (5:_setting)_Outpatient: 0, (filled with 0)
# Number of missing values in (5:_setting)_Trauma: 0, (filled with 0)
# ###############################################
# Number of missing values in 6:_anaesthesia_EEG used (is protective): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Cont. Analgesic (painkiller: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Cont. Temp. Monitoring: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Benzo premed (RISKFactor): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Intraop. nociception monitored (e.g. NOL) (stress/pain monitor): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_TCI (Target Controlled Infusion: drugs on level of brain receptors. Algorithm, so should be better than TIVA weight-based.): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_TIVA (Total intravenous anesthesia: based on only weight.): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_SEVO (gas through the mask, inhalation - not intravenous like TCI/TIVA): 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_General anaesthesia: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Sedation: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Spinal: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Epidural: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Upper extremity: 0, (filled with 0)
# Number of missing values in 6:_anaesthesia_Lower extremity: 0, (filled with 0)
# ###############################################
# Number of missing values in 7:_prevention_PONV_(SOP used): 0, (filled with 0)
# Number of missing values in 7:_prevention_Preemptive_Analgesia_(SOP used) - painkillers: 0, (filled with 0)
# Number of missing values in 7:_prevention_EMLA offered - anesthetic cream: 0, (filled with 0)
# Number of missing values in 7:_prevention_Paticipation_from_relatives: 0, (filled with 0)
# Number of missing values in 7:_prevention_Atropin used: 0, (filled with 0)
# Number of missing values in 7:_prevention_Capnography_used_(w_sedatives): 0, (filled with 0)
# Number of missing values in 7:_prevention_Eyeblinds/earplugs_offerede: 0, (filled with 0)
# ###############################################
# Number of missing values in 11:_rass_score_BI: 9, (filled with 0)
# Number of missing values in 11:_rass_score_AP: 15, (filled with 0)
# Number of missing values in 11:_rass_score_DP: 16, (filled with 0)
# Number of missing values in 11:_rass_score_HV: 12, (filled with 0)
# ###############################################
# Column: 12.1:_disorientation_BI, Dominant Class: 0.0, Frequency: 1409, Missing Values: 2
# Column: 12.2:_inappropriate_behavior_BI, Dominant Class: 0.0, Frequency: 1414, Missing Values: 1
# Column: 12.3:_inappropriate_communication_BI, Dominant Class: 0.0, Frequency: 1409, Missing Values: 1
# Column: 12.4:_illusions/hallucinations_BI, Dominant Class: 0.0, Frequency: 1419, Missing Values: 1
# Column: 12.5:_psychomotor_retardation_BI, Dominant Class: 0.0, Frequency: 1409, Missing Values: 2
# Column: 12.1:_disorientation_AP, Dominant Class: 0.0, Frequency: 1204, Missing Values: 10
# Column: 12.2:_inappropriate_behavior_AP, Dominant Class: 0.0, Frequency: 1362, Missing Values: 10
# Column: 12.3:_inappropriate_communication_AP, Dominant Class: 0.0, Frequency: 1231, Missing Values: 12
# Column: 12.4:_illusions/hallucinations_AP, Dominant Class: 0.0, Frequency: 1379, Missing Values: 13
# Column: 12.5:_psychomotor_retardation_AP, Dominant Class: 0.0, Frequency: 1018, Missing Values: 12
# Column: 12.1:_disorientation_DP, Dominant Class: 0.0, Frequency: 1410, Missing Values: 4
# Column: 12.2:_inappropriate_behavior_DP, Dominant Class: 0.0, Frequency: 1412, Missing Values: 4
# Column: 12.3:_inappropriate_communication_DP, Dominant Class: 0.0, Frequency: 1413, Missing Values: 4
# Column: 12.4:_illusions/hallucinations_DP, Dominant Class: 0.0, Frequency: 1413, Missing Values: 6
# Column: 12.5:_psychomotor_retardation_DP, Dominant Class: 0.0, Frequency: 1383, Missing Values: 4
# Column: 12.1:_disorientation_HV, Dominant Class: 0.0, Frequency: 1210, Missing Values: 7
# Column: 12.2:_inappropriate_behavior_HV, Dominant Class: 0.0, Frequency: 1357, Missing Values: 11
# Column: 12.3:_inappropriate_communication_HV, Dominant Class: 0.0, Frequency: 1240, Missing Values: 6
# Column: 12.4:_illusions/hallucinations_HV, Dominant Class: 0.0, Frequency: 1382, Missing Values: 9
# Column: 12.5:_psychomotor_retardation_HV, Dominant Class: 0.0, Frequency: 1024, Missing Values: 7
# ###############################################
# Number of missing values in 13:_moyb_BI: 25, (filled with 0)
# Number of missing values in 13:_moyb_AP: 42, (filled with 0)
# Number of missing values in 13:_moyb_DP: 25, (filled with 0)
# Number of missing values in 13:_moyb_HV: 22, (filled with 0)
# ###############################################
# Number of missing values in 14_anxiety_nrs_BI: 9, (filled with 0)
# Number of missing values in 14_anxiety_AP: 135, (filled with 0)
# Number of missing values in 14_anxiety_DP: 16, (filled with 0)
# Number of missing values in 14_anxiety_HV: 14, (filled with 0)
# ###############################################
# Number of missing values in 15_stress_nrs_BI: 7, (filled with 0)
# Number of missing values in 15:_stress_AP: 134, (filled with 0)
# Number of missing values in 15:_stress_DP: 15, (filled with 0)
# Number of missing values in 15:_stress_nrs_HV: 14, (filled with 0)
# ###############################################
# Column: 16:_general_well-being_nrs _0-10_BI, Dominant Class: 10.0, Frequency: 413, Missing Values: 10
# Column: 16:_general_well-being_AP, Dominant Class: 10.0, Frequency: 583, Missing Values: 141
# Column: 16:_general_well-being_DP, Dominant Class: 10.0, Frequency: 627, Missing Values: 20
# Column: 16:_general_well-being_nrs_HV, Dominant Class: 10.0, Frequency: 770, Missing Values: 13
# ###############################################
# Number of missing values in 18a:_nausea_BI: 8, (filled with 0)
# Number of missing values in 18a:_nausea_AP: 24, (filled with 0)
# Number of missing values in 18a:_nausea_DP: 35, (filled with 0)
# Number of missing values in 18a:_nausea_HV: 16, (filled with 0)
# ###############################################
# Number of missing values in 18b_vomiting_nrs_BI: 12, (filled with 0)
# Number of missing values in 18b:_vomiting_AP: 23, (filled with 0)
# Number of missing values in 18b:_vomiting_DP: 14, (filled with 0)
# ###############################################
# Number of missing values in 19:_patient_uses_visual_aids_BI: 0, (filled with 0)
# Number of missing values in 19a:_visual_aid_present_BI: 0, (filled with 0)
# Number of missing values in 20: patient_uses_hearing_aids_BI: 0, (filled with 0)
# Number of missing values in 20a:_hearing_aid_present_BI: 0, (filled with 0)
# Number of missing values in 21: patient_uses_dentures_BI: 0, (filled with 0)
# Number of missing values in 21a: dentures_present_BI: 0, (filled with 0)
# Number of missing values in 19a:_visual_aid_present_AP: 0, (filled with 0)
# Number of missing values in 20a:_hearing_aid_present_AP: 0, (filled with 0)
# Number of missing values in 21a: dentures_present_AP: 0, (filled with 0)
# ###############################################
# Number of missing values in 22:_fluids_p.o._>200_ml_BI: 54, (filled with mean)
# ###############################################
# Number of missing values in 22:_fluids_p.o._>200_ml_DP: 74, (filled with 0)
# ###############################################
# Number of missing values in 23:_thirst_feeling: _nrs_0-10_BI: 33, (filled with mean)
# Number of missing values in 23:_thirst_feeling_AP: 275, (filled with mean)
# Number of missing values in 23:_thirst_feeling:_DP: 223, (filled with mean)
# ###############################################
# Column: 24:_temperature _c_BI, Dominant Class: 36.5, Frequency: 98, Missing Values: 741
# Column: 24:_temperature _AP, Dominant Class: 36.0, Frequency: 125, Missing Values: 807
# Column: 24:_temperature_DP, Dominant Class: 36.0, Frequency: 223, Missing Values: 389
# ###############################################
# Number of missing values in 25:_noise_reduction_performed_BI: 236, (filled with 0)
# Number of missing values in 25:_noise_reduction_DP: 350, (filled with 0)
# ###############################################
# Column: 10:_shivering_AP, Dominant Class: 0.0, Frequency: 1344, Missing Values: 19
# Column: 10:_shivering_DP, Dominant Class: 0.0, Frequency: 1382, Missing Values: 15
# Column: 10:_shivering_HV, Dominant Class: 0.0, Frequency: 1343, Missing Values: 10
# ###############################################
# Number of missing values in 17:_bladder_AP: 36, (filled with 0)
# Number of missing values in 17:_bladder_DP: 22, (filled with 0)
# ###############################################
# Column: 28:_quality-evaluation_of_screening_BI, Dominant Class: 2.0, Frequency: 1291, Missing Values: 39
# Column: 28:_quality-evaluation_of_screening_AP, Dominant Class: 2.0, Frequency: 1002, Missing Values: 100
# Column: 28:_quality-evaluation_of_screening_DP, Dominant Class: 2.0, Frequency: 1293, Missing Values: 51
# ###############################################
# Number of missing values in 31: length_of_patient_stay_in_pacu/recovery_room: 51, (filled with mean)
# ###############################################

# %% [markdown]
# ## Imputation using Imputers

# %%
# We use complex imputation for columns that have a lot of missing values
df = df_unprocessed.copy()
# Remove target columns before imputing to avoid data leakage
target_substrings = ['_disorientation', '_inappropriate_behavior',
              '_inappropriate_communication',
              'illusions/hallucinations', '_psychomotor_retardation']
target_cols = [col for col in df.columns if any(sub in col.lower() for sub in target_substrings)]
# target cols do not contain BI cols
target_cols = [col for col in target_cols if 'BI' not in col]
# Save the target columns for later
df_targets = df[target_cols]
df.drop(target_cols, axis=1, inplace=True)
# Impute the rest of the columns using KNN imputer
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
# Add the target columns back
df_imputed = pd.concat([df_imputed, df_targets], axis=1)
df_imputed.to_csv(path.join(save_data_path, 'df_imputed_complex.csv'), index=False)
# Check if there are any NaN values left
